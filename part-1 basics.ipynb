# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ### Part 1 Basics

# %% [markdown]
# ## NLP with "Natural Language Processing with Python" - Steven Bird

# %% [markdown]
# ### Loading Book Module

# %%
from nltk.book import *

# %% [markdown]
# ### Different Types of Word Searching

# %% [markdown]
# #### Searching the text with 'concordance'

# %%
text1.concordance("flood")
# Out:
# Displaying 15 of 15 matches:
# " -- MONTGOMERY ' S WORLD BEFORE THE FLOOD . " Io ! Paean ! Io ! sing . To the
# aling voyage was welcome ; the great flood - gates of the wonder - world swung
#  animated mass that has survived the flood ; most monstrous and most mountainou
# lies his business , which a Noah ' s flood would not interrupt , though it over
# ship swinging to her anchor with the flood - tide , was now obliquely pointing
# - " Sweet fields beyond the swelling flood , Stand dressed in living green . So
# r . Yea , foolish mortals , Noah ' s flood is not yet subsided ; two thirds of
#  animals there are certain valves or flood - gates in many of their veins , whe
# you carry them the news that another flood had come ; they would only answer --
# r incalculable seniors ; I am , by a flood , borne back to that wondrous period
# stle , and the Kremlin . In Noah ' s flood he despised Noah ' s Ark ; and if ev
# ...

# %% [markdown]
# #### Searching the text with 'similar'

# %%
text9.similar("monstrous")
# Out:
# old young silent good two little only new big ordinary third humble
# proud rich same enormous poor greatest three crooked

# %% [markdown]
# #### Examine contexts

# %%
text2.common_contexts(["monstrous", "very"])
# Out:
# a_pretty am_glad a_lucky is_pretty be_glad

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# %% [markdown]
# #### Counting Vocabulary

# %%
len(text3)
# Out:
# 44764

# %% [markdown]
# #### Generating a sorted list of vocabulary items

# %%
sorted(set(text3))
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %% [markdown]
# ####  Calculating the measure of the lexical richness (text)

# %%
from __future__ import division
len(text3) / len(set(text3))
# Out:
# 16.050197203298673

# %% [markdown]
# #### Computing the percentage of the text is taken up by a specific word:

# %%
text3.count("smote")
100 * text4.count('a') / len(text4)
# Out:
# 1.457973123627309

# %% [markdown]
# ####  Lexical diversity

# %% [markdown]
# ##### define new function, lexical_diversity()

# %%
def lexical_diversity(text):
...     return len(text) / len(set(text)) 
...

# %%
lexical_diversity(text3)
# Out:
# 16.050197203298673

# %% [markdown]
# ##### Define percentage()

# %%
def percentage(count, total): 
...     return 100 * count / total
...

# %%
lexical_diversity(text4)
# Out:
# 15.111167154241905

# %%
 percentage(4, 5)
# Out:
# 80.0

# %%
 percentage(text4.count('a'), len(text4))
# Out:
# 1.457973123627309

# %% [markdown]
# -----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Python Lists

# %% [markdown]
# -----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Lists in Python

# %%
 senten1 = ['Iam', 'Gokul', ',How', 'are', 'You', '.']

# %%
senten1
# Out:
# ['Iam', 'Gokul', ',How', 'are', 'You', '.']

# %%
senten2 = ['Iam', 'from', 'India']

# %%
senten2
# Out:
# ['Iam', 'from', 'India']

# %%
senten3 = ['learning', 'Python']
senten3
# Out:
# ['learning', 'Python']

# %% [markdown]
# #### Merging sentences

# %%
senten1 + senten2
# Out:
# ['Iam', 'Gokul', ',How', 'are', 'You', '.', 'Iam', 'from', 'India']

# %% [markdown]
# ##### Append ()

# %%
senten3.append("is easy")
senten3
# Out:
# ['learning', 'Python', 'is easy']

# %% [markdown]
# ### Indexing Lists

# %%
text3[26]
# Out:
# 'face'

# %%
text3.index('face')
# Out:
# 26

# %% [markdown]
# #### Accessing the words of a text

# %%
text5[16715:16735]
# Out:
# ['U86',
#  'thats',
#  'why',
#  'something',
#  'like',
#  'gamefly',
#  'is',
#  'so',
#  'good',
#  'because',
#  'you',
#  'can',
#  'actually',
#  'play',
#  'a',
#  'full',
#  'game',
#  'without',
#  'buying',
#  'it']

# %%
text2[141525:]
# Out:
# ['among',
#  'the',
#  'merits',
#  'and',
#  'the',
#  'happiness',
#  'of',
#  'Elinor',
#  'and',
#  'Marianne',
#  ',',
#  'let',
#  'it',
#  'not',
#  'be',
#  'ranked',
#  'as',
#  'the',
#  'least',
#  'considerable',
#  ',',
#  'that',
#  'though',
#  'sisters',
#  ',',
#  'and',
#  'living',
#  'almost',
#  'within',
#  'sight',
#  'of',
#  'each',
#  'other',
#  ',',
#  'they',
#  'could',
#  'live',
#  'without',
#  'disagreement',
#  'between',
#  'themselves',
#  ',',
#  'or',
#  'producing',
#  'coolness',
#  'between',
#  'their',
#  'husbands',
#  '.',
#  'THE',
#  'END']

# %% [markdown]
# ### Variables

# %%
 my_sent = ['Bravely', 'bold', 'Sir', 'Robin', ',', 'rode',
... 'forth', 'from', 'Camelot', '.']

# %%
noun_phrase = my_sent[1:4]
noun_phrase
# Out:
# ['bold', 'Sir', 'Robin']

# %%
words = sorted(noun_phrase)
words
# Out:
# ['Robin', 'Sir', 'bold']

# %% [markdown]
# ### Strings

# %%
name = 'Gokul'
name[0]
# Out:
# 'G'

# %%
name[:4]
# Out:
# 'Goku'

# %% [markdown]
# #### Multiplication and addition with strings

# %%
name * 3
# Out:
# 'GokulGokulGokul'

# %%
name + '!'
# Out:
# 'Gokul!'

# %% [markdown]
# ####  Join the words of a list

# %%
 ' '.join(['Gokul', 'K S'])
# Out:
# 'Gokul K S'

# %% [markdown]
# #### Spliting

# %%
'Gokul K S'.split()
# Out:
# ['Gokul', 'K', 'S']

# %% [markdown]
# ## Computing with Language: Simple Statistics

# %%
 saying = ['After', 'all', 'is', 'said', 'and', 'done',
... 'more', 'is', 'said', 'than', 'done']

# %%
tokens = set(saying)
tokens = sorted(tokens)
tokens[-2:]
# Out:
# ['said', 'than']

# %% [markdown]
# #### Frequency Distributions

# %%
fdist1 = FreqDist(text1)
fdist1
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
vocabulary1 = fdist1.keys() 
fdist1['whale']
# Out:
# 906
